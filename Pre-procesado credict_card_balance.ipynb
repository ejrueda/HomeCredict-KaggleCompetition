# %%
import numpy as np
import pandas as pd

# %%
credict_cb = pd.read_csv('./data/credit_card_balance.csv')

# %%
credict_cb = credict_cb.set_index(credict_cb.columns[1])
credict_cb = credict_cb.drop('SK_ID_PREV',axis=1)
print(credict_cb.shape)
# Out:
# (3840312, 21)

# %%
credict_cb.head()
# Out:
#             MONTHS_BALANCE  AMT_BALANCE  AMT_CREDIT_LIMIT_ACTUAL  \
# SK_ID_CURR
# 378907                  -6       56.970                   135000
# 363914                  -1    63975.555                    45000
# 371185                  -7    31815.225                   450000
# 337855                  -4   236572.110                   225000
# 126868                  -1   453919.455                   450000
#
#             AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  \
# SK_ID_CURR
# 378907                           0.0                 877.5
# 363914                        2250.0                2250.0
# 371185                           0.0                   0.0
# 337855                        2250.0                2250.0
# 126868                           0.0               11547.0
#
#             AMT_DRAWINGS_OTHER_CURRENT  AMT_DRAWINGS_POS_CURRENT  \
# SK_ID_CURR
# 378907                             0.0                     877.5
# 363914                             0.0                       0.0
# 371185                             0.0                       0.0
# 337855                             0.0                       0.0
# 126868                             0.0                   11547.0
#
#             AMT_INST_MIN_REGULARITY  AMT_PAYMENT_CURRENT  \
# SK_ID_CURR
# 378907                     1700.325               1800.0
# 363914                     2250.000               2250.0
# 371185                     2250.000               2250.0
# 337855                    11795.760              11925.0
# 126868                    22924.890              27000.0
#
#             AMT_PAYMENT_TOTAL_CURRENT     ...      AMT_RECIVABLE  \
# SK_ID_CURR                                ...
# 378907                         1800.0     ...              0.000
# 363914                         2250.0     ...          64875.555
# 371185                         2250.0     ...          31460.085
# 337855                        11925.0     ...         233048.970
# 126868                        27000.0     ...         453919.455
#
#             AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  \
# SK_ID_CURR
# 378907                     0.000                       0.0
# 363914                 64875.555                       1.0
# 371185                 31460.085                       0.0
# 337855                233048.970                       1.0
# 126868                453919.455                       0.0
#
#             CNT_DRAWINGS_CURRENT  CNT_DRAWINGS_OTHER_CURRENT  \
# SK_ID_CURR
# 378907                         1                         0.0
# 363914                         1                         0.0
# 371185                         0                         0.0
# 337855                         1                         0.0
# 126868                         1                         0.0
#
#             CNT_DRAWINGS_POS_CURRENT  CNT_INSTALMENT_MATURE_CUM  \
# SK_ID_CURR
# 378907                           1.0                       35.0
# 363914                           0.0                       69.0
# 371185                           0.0                       30.0
# 337855                           0.0                       10.0
# 126868                           1.0                      101.0
#
#             NAME_CONTRACT_STATUS SK_DPD  SK_DPD_DEF
# SK_ID_CURR
# 378907                    Active      0           0
# 363914                    Active      0           0
# 371185                    Active      0           0
# 337855                    Active      0           0
# 126868                    Active      0           0
#
# [5 rows x 21 columns]

# %%
# %run ./code/label_encoder.py
credict_cb = credict_cb.groupby(credict_cb.index).last()
credict_cb = label_encoder(credict_cb)
credict_cb.shape
# Out:
# (103558, 21)

# %%
credict_cb.to_csv('./data/data_procesada/credict_cb_1.csv')
