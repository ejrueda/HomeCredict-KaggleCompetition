# %%
import pandas as pd
import numpy as np

# %%
data_train = pd.read_csv('./data/data_procesada/data_train_1.csv',index_col=0)
y_train = pd.read_csv('./data/data_procesada/y_train_1.csv',index_col=0,names=['SK_ID_CURR','TARGET'])
data_test = pd.read_csv('./data/data_procesada/data_test_1.csv',index_col=0)
bureau = pd.read_csv('./data/data_procesada/bureau_1.csv', index_col=0)
previus_app = pd.read_csv('./data/data_procesada/pre_app_1.csv', index_col=0)
credict_cb = pd.read_csv('./data/data_procesada/credict_cb_1.csv', index_col=0)
posh_cb = pd.read_csv('./data/data_procesada/posh_cb_1.csv', index_col=0)

# %%
data_test.head()
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100001             Cash loans           F            N               Y
# 100005             Cash loans           M            N               Y
# 100013             Cash loans           M            Y               Y
# 100028             Cash loans           F            N               Y
# 100038             Cash loans           M            Y               N
#
#             CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100001                 0          135000.0    568800.0      20560.5
# 100005                 0           99000.0    222768.0      17370.0
# 100013                 0          202500.0    663264.0      69777.0
# 100028                 2          315000.0   1575000.0      49018.5
# 100038                 1          180000.0    625500.0      32067.0
#
#             AMT_GOODS_PRICE NAME_INCOME_TYPE             ...              \
# ...

# %%
data_train.head()
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100002             Cash loans           M            N               Y
# 100007             Cash loans           M            N               Y
# 100024        Revolving loans           M            Y               Y
# 100031             Cash loans           F            N               Y
# 100045             Cash loans           F            N               Y
#
#             CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100002                 0          202500.0    406597.5      24700.5
# 100007                 0          121500.0    513000.0      21865.5
# 100024                 0          135000.0    427500.0      21375.0
# 100031                 0          112500.0    979992.0      27076.5
# 100045                 0           99000.0    247275.0      17338.5
#
#             AMT_GOODS_PRICE NAME_INCOME_TYPE             ...              \
# ...

# %%
y_train.head()
# Out:
#             TARGET
# SK_ID_CURR
# 100002           1
# 100007           0
# 100024           0
# 100031           1
# 100045           0

# %%
bureau.head()
# Out:
#             CREDIT_ACTIVE  CREDIT_CURRENCY  DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# SK_ID_CURR
# 100001                  0                0         -320                   0
# 100002                  2                0        -1043                   0
# 100003                  0                0         -606                   0
# 100004                  2                0         -408                   0
# 100005                  0                0          -62                   0
#
#             DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  AMT_CREDIT_MAX_OVERDUE  \
# SK_ID_CURR
# 100001                    411.0            -1328.0                     NaN
# 100002                     62.0             -967.0                     0.0
# 100003                   1216.0             -621.0                     0.0
# 100004                   -382.0             -382.0                     0.0
# 100005                    122.0             -123.0                     0.0
#
# ...

# %%
previus_app.head()
# Out:
#         NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  \
# 100001                   1     3951.000          24835.5     23787.0
# 100002                   1     9251.775         179055.0    179055.0
# 100003                   1     6737.310          68809.5     68053.5
# 100004                   1     5357.250          24282.0     20106.0
# 100005                   1     4813.200          44617.5     40153.5
#
#         AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  WEEKDAY_APPR_PROCESS_START  \
# 100001            2520.0          24835.5                           0
# 100002               0.0         179055.0                           2
# 100003            6885.0          68809.5                           2
# 100004            4860.0          24282.0                           0
# 100005            4464.0          44617.5                           4
#
#         HOUR_APPR_PROCESS_START  FLAG_LAST_APPL_PER_CONTRACT  \
# 100001                       13                            1
# ...

# %%
credict_cb.head()
# Out:
#             MONTHS_BALANCE  AMT_BALANCE  AMT_CREDIT_LIMIT_ACTUAL  \
# SK_ID_CURR
# 100006                  -6         0.00                   270000
# 100011                 -69    166628.16                   180000
# 100013                 -33         0.00                   157500
# 100021                 -11         0.00                   675000
# 100023                  -6         0.00                   225000
#
#             AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  \
# SK_ID_CURR
# 100006                           NaN                   0.0
# 100011                           0.0                   0.0
# 100013                           0.0                   0.0
# 100021                           NaN                   0.0
# 100023                           NaN                   0.0
#
#             AMT_DRAWINGS_OTHER_CURRENT  AMT_DRAWINGS_POS_CURRENT  \
# SK_ID_CURR
# 100006                             NaN                       NaN
# ...

# %%
posh_cb.head()
# Out:
#             MONTHS_BALANCE  CNT_INSTALMENT  CNT_INSTALMENT_FUTURE  \
# SK_ID_CURR
# 100001                 -56             4.0                    3.0
# 100002                 -15            24.0                   20.0
# 100003                 -28             6.0                    6.0
# 100004                 -26             4.0                    3.0
# 100005                 -15             9.0                    0.0
#
#             NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# SK_ID_CURR
# 100001                         0       0           0
# 100002                         0       0           0
# 100003                         0       0           0
# 100004                         0       0           0
# 100005                         4       0           0

# %%
data_train = pd.merge(data_train, previus_app, left_index=True, right_index=True, how='left')
data_test = pd.merge(data_test, previus_app, left_index=True, right_index=True, how='left')

data_train = pd.merge(data_train, bureau, left_index=True, right_index=True, how='left')
data_test = pd.merge(data_test, bureau, left_index=True, right_index=True, how='left')

data_train = pd.merge(data_train, credict_cb, left_index=True, right_index=True, how='left')
data_test = pd.merge(data_test, credict_cb, left_index=True, right_index=True, how='left')

data_train = pd.merge(data_train, posh_cb, left_index=True, right_index=True, how='left')
data_test = pd.merge(data_test, posh_cb, left_index=True, right_index=True, how='left')

# %%
data_train.head()
# Out:
#            NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100002               Cash loans           M            N               Y
# 100007               Cash loans           M            N               Y
# 100024          Revolving loans           M            Y               Y
# 100031               Cash loans           F            N               Y
# 100045               Cash loans           F            N               Y
#
#             CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  \
# SK_ID_CURR
# 100002                 0          202500.0      406597.5        24700.5
# 100007                 0          121500.0      513000.0        21865.5
# 100024                 0          135000.0      427500.0        21375.0
# 100031                 0          112500.0      979992.0        27076.5
# 100045                 0           99000.0      247275.0        17338.5
#
#             AMT_GOODS_PRICE_x NAME_INCOME_TYPE      ...       \
# ...

# %%
# %run ./code/label_encoder.py
data_train = label_encoder(data_train)
data_test = label_encoder(data_test)

# %%
data_train.loc[:,data_train.count()<data_train.shape[0]].columns
# Out:
# Index(['AMT_ANNUITY_x', 'AMT_GOODS_PRICE_x', 'APARTMENTS_AVG',
#        'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG',
#        'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG',
#        ...
#        'CNT_INSTALMENT_MATURE_CUM', 'NAME_CONTRACT_STATUS_y', 'SK_DPD_x',
#        'SK_DPD_DEF_x', 'MONTHS_BALANCE_y', 'CNT_INSTALMENT',
#        'CNT_INSTALMENT_FUTURE', 'NAME_CONTRACT_STATUS', 'SK_DPD_y',
#        'SK_DPD_DEF_y'],
#       dtype='object', length=132)

# %%
#lo mismo para el data_train
col_mean_train = (data_train.loc[:,data_train.count()<data_train.shape[0]].min())
dict_col_mean_train = {}
for i in range(len(col_mean_train)):
    dict_col_mean_train[col_mean_train.index[i]] = col_mean_train[i]
    
#lo mismo para el data_test
col_mean_test = (data_test.loc[:,data_test.count()<data_test.shape[0]].min())
dict_col_mean_test = {}
for i in range(len(col_mean_test)):
    dict_col_mean_test[col_mean_test.index[i]] = col_mean_test[i]

# %%
data_train = data_train.fillna(value=col_mean_train)
data_test = data_test.fillna(value=col_mean_test)

# %%
from sklearn.ensemble import GradientBoostingClassifier

GBC = GradientBoostingClassifier(n_estimators=150,verbose=1, learning_rate=.5)
GBC.fit(data_train, np.ravel(y_train))
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3013            1.07m
#          2           1.2670            1.05m
#          3           1.2450           59.99s
#          4           1.2324           58.92s
#          5           1.2224           56.89s
#          6           1.2140           56.26s
#          7           1.2069           55.70s
#          8           1.2020           54.98s
#          9           1.1968           58.47s
#         10           1.1901            1.02m
#         20           1.1617           49.14s
#         30           1.1405           43.37s
#         40           1.1280           38.04s
#         50           1.1156           33.94s
#         60           1.1072           30.14s
#         70           1.0972           26.33s
#         80           1.0885           22.62s
#         90           1.0817           19.03s
#        100           1.0735           15.66s
# ...

# %%
GBC.score(data_train, np.ravel(y_train))
# Out:
# 0.74481369587109769

# %%
predict = GBC.predict_proba(data_test)[:,1]

# %%
predict
# Out:
# array([ 0.2363176 ,  0.68869921,  0.21738393, ...,  0.19473984,
#         0.24466057,  0.69809603])

# %%
#sin correlación de datos
result = pd.DataFrame(data=predict, index=data_test.index, columns=['TARGET'])
result.index.name = 'SK_ID_CURR'
result.to_csv('./results/submission_test_50.csv')

# %% [markdown]
# el 46 es filtrando los NaN con ceros

# %%
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier(n_estimators=15, n_jobs=3)
RFC.fit(data_train, np.ravel(y_train))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=15, n_jobs=3,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
RFC.score(data_train, np.ravel(y_train))
# Out:
# 0.9962739174219537

# %%
predict = RFC.predict_proba(data_test)[:,1]

# %%
predict
# Out:
# array([ 0.26666667,  0.6       ,  0.33333333, ...,  0.53333333,
#         0.33333333,  0.8       ])

# %%
#sin correlación de datos
result = pd.DataFrame(data=predict, index=data_test.index, columns=['TARGET'])
result.index.name = 'SK_ID_CURR'
result.to_csv('./results/submission_test_47.csv')
